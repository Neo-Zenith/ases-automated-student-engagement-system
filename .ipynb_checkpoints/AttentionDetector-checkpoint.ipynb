# %%
#!pip install -r requirements.txt
# Out:
# Requirement already satisfied: imutils in c:\users\d188878\anaconda3\envs\mlda\lib\site-packages (from -r requirements.txt (line 1)) (0.5.4)
# Requirement already satisfied: numpy in c:\users\d188878\anaconda3\envs\mlda\lib\site-packages (from -r requirements.txt (line 2)) (1.21.5)
# Collecting argparse
#   Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Collecting dlib
#   Using cached dlib-19.24.0.tar.gz (3.2 MB)
# Requirement already satisfied: scipy in c:\users\d188878\anaconda3\envs\mlda\lib\site-packages (from -r requirements.txt (line 5)) (1.7.3)
# Requirement already satisfied: opencv-python in c:\users\d188878\anaconda3\envs\mlda\lib\site-packages (from -r requirements.txt (line 6)) (4.6.0.66)
# Building wheels for collected packages: dlib
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\d188878\anaconda3\envs\mlda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"'; __file__='"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\d188878\AppData\Local\Temp\pip-wheel-zcxoog7a'
#        cwd: C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\
#   Complete output (68 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#   running build_ext
#   C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(cmake_version) < '3.1.0':
#   Building extension for Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
#   Invoking CMake setup: 'cmake C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\build\lib.win-amd64-3.9 -DPYTHON_EXECUTABLE=C:\Users\d188878\anaconda3\envs\mlda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\build\lib.win-amd64-3.9 -A x64'
#   -- Building for: NMake Makefiles
#   CMake Error at CMakeLists.txt:5 (message):
#
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#     You must use Visual Studio to build a python extension on windows.  If you
#     are getting this error it means you have not installed Visual C++.  Note
#     that there are many flavors of Visual Studio, like Visual Studio for C#
#     development.  You need to install Visual Studio for C++.
#
#
#     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#   Building wheel for dlib (setup.py): started
#   Building wheel for dlib (setup.py): finished with status 'error'
#   Running setup.py clean for dlib
# Failed to build dlib
# Installing collected packages: dlib, argparse
#     Running setup.py install for dlib: started
#     Running setup.py install for dlib: finished with status 'error'
#
#   -- Configuring incomplete, errors occurred!
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 222, in <module>
#       setup(
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\__init__.py", line 87, in setup
#       return distutils.core.setup(**attrs)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#       return run_commands(dist)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#       dist.run_commands()
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#       self.run_command(cmd)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#       super().run_command(command)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\wheel\bdist_wheel.py", line 299, in run
#       self.run_command('build')
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#       super().run_command(command)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\command\build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#       super().run_command(command)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#       cmd_obj.run()
#     File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 134, in run
#       self.build_extension(ext)
#     File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 171, in build_extension
#       subprocess.check_call(cmake_setup, cwd=build_folder)
#     File "C:\Users\d188878\anaconda3\envs\mlda\lib\subprocess.py", line 373, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\build\\lib.win-amd64-3.9', '-DPYTHON_EXECUTABLE=C:\\Users\\d188878\\anaconda3\\envs\\mlda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\build\\lib.win-amd64-3.9', '-A', 'x64']' returned non-zero exit status 1.
#   ----------------------------------------
#   ERROR: Failed building wheel for dlib
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\d188878\anaconda3\envs\mlda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"'; __file__='"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\d188878\AppData\Local\Temp\pip-record-8v359tx7\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\d188878\anaconda3\envs\mlda\Include\dlib'
#          cwd: C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\
#     Complete output (72 lines):
#     running install
#     C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running build
#     running build_py
#     package init file 'tools\python\dlib\__init__.py' not found (or not a regular file)
#     running build_ext
#     C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py:129: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#       if LooseVersion(cmake_version) < '3.1.0':
#     Building extension for Python 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
#     Invoking CMake setup: 'cmake C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\tools\python -DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\build\lib.win-amd64-3.9 -DPYTHON_EXECUTABLE=C:\Users\d188878\anaconda3\envs\mlda\python.exe -DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\build\lib.win-amd64-3.9 -A x64'
#     -- Building for: NMake Makefiles
#     CMake Error at CMakeLists.txt:5 (message):
#
#
#
#       !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#       You must use Visual Studio to build a python extension on windows.  If you
#       are getting this error it means you have not installed Visual C++.  Note
#       that there are many flavors of Visual Studio, like Visual Studio for C#
#       development.  You need to install Visual Studio for C++.
#
#
#       !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#
#
#
#
#     -- Configuring incomplete, errors occurred!
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 222, in <module>
#         setup(
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\__init__.py", line 87, in setup
#         return distutils.core.setup(**attrs)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\core.py", line 148, in setup
#         return run_commands(dist)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\core.py", line 163, in run_commands
#         dist.run_commands()
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 967, in run_commands
#         self.run_command(cmd)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#         super().run_command(command)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#         cmd_obj.run()
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\command\install.py", line 68, in run
#         return orig.install.run(self)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\command\install.py", line 664, in run
#         self.run_command('build')
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#         super().run_command(command)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#         cmd_obj.run()
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\command\build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\dist.py", line 1214, in run_command
#         super().run_command(command)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\site-packages\setuptools\_distutils\dist.py", line 986, in run_command
#         cmd_obj.run()
#       File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 134, in run
#         self.build_extension(ext)
#       File "C:\Users\d188878\AppData\Local\Temp\pip-install-iufiv7h1\dlib_13bd0b749c0046f8b32869c79bfe351d\setup.py", line 171, in build_extension
#         subprocess.check_call(cmake_setup, cwd=build_folder)
#       File "C:\Users\d188878\anaconda3\envs\mlda\lib\subprocess.py", line 373, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['cmake', 'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\tools\\python', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY=C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\build\\lib.win-amd64-3.9', '-DPYTHON_EXECUTABLE=C:\\Users\\d188878\\anaconda3\\envs\\mlda\\python.exe', '-DCMAKE_LIBRARY_OUTPUT_DIRECTORY_RELEASE=C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\build\\lib.win-amd64-3.9', '-A', 'x64']' returned non-zero exit status 1.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\d188878\anaconda3\envs\mlda\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"'; __file__='"'"'C:\\Users\\d188878\\AppData\\Local\\Temp\\pip-install-iufiv7h1\\dlib_13bd0b749c0046f8b32869c79bfe351d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\d188878\AppData\Local\Temp\pip-record-8v359tx7\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\d188878\anaconda3\envs\mlda\Include\dlib' Check the logs for full command output.

# %%
# import the necessary packages
from scipy.spatial import distance as dist
from imutils.video import FileVideoStream
from imutils.video import VideoStream
from imutils import face_utils
import numpy as np
import argparse
import imutils
import time
import dlib
import cv2
