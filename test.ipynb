# %% [markdown]
# <a href="https://colab.research.google.com/github/Neo-Zenith/MLDA-Deep-Learning-Week/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
